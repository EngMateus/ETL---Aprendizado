# %%
import pandas as pd
import numpy as np
import os

# %%
pwd
# Out:
# 'C:\\Users\\Mateus\\Desktop\\Projeto_Wesley\\Dados Crus'

# %%
atual = 'C:\\Users\\Mateus\\Desktop\\Projeto_Wesley'

# %%
pwd
# Out:
# 'C:\\Users\\Mateus\\Desktop\\Projeto_Wesley\\Dados Crus'

# %%
### Arquivo csv esta na pasta de dados brutos
caminho_dados_crus = "Projeto_Wesley/Dados Cru"

# %%
dados = pd.read_csv('sigec-multa-de-fiscalizacao.csv',encoding='ISO-8859-1',sep=';')

# %%
dados.head()
# Out:
#   DatGeracaoConjuntoDados  Codcvnarr  AnmArrecadacao DatVencimentoTitulo  \
# 0              2024-09-09    2940946          202109          2021-09-21
# 1              2024-09-09    2600226          201412          2015-01-02
# 2              2024-09-09    2600226          201412          2015-01-02
# 3              2024-09-09    2940946          201708          2017-11-07
# 4              2024-09-09    2940946          201708          2018-01-06
#
#   DatIncidenciaMultaMora DatPagamentoTitulo  QtdDiasEmAtraso  \
# 0             2021-09-12         2021-09-15             -6.0
# 1             2015-06-22         2015-06-24            173.0
# 2             2015-04-27         2015-06-24            173.0
# 3             2017-12-30         2018-03-12            125.0
# 4             2017-12-30         2018-05-07            121.0
#
#                                  SigNomAgente      NumCPFCNPJ  \
# 0  WOBBEN WINDPOWER INDÚSTRIA E COMÉRCIO LTDA   1027335000166
# ...

# %% [markdown]
# ##### VERIFICANDO INFORMAÇÕES GERAIS DAS COLUNAS

# %%
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6782 entries, 0 to 6781
# Data columns (total 19 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   DatGeracaoConjuntoDados  6782 non-null   object
#  1   Codcvnarr                6782 non-null   int64
#  2   AnmArrecadacao           6782 non-null   int64
#  3   DatVencimentoTitulo      6782 non-null   object
#  4   DatIncidenciaMultaMora   6781 non-null   object
#  5   DatPagamentoTitulo       5574 non-null   object
#  6   QtdDiasEmAtraso          5574 non-null   float64
#  7   SigNomAgente             6782 non-null   object
#  8   NumCPFCNPJ               6782 non-null   int64
#  9   NomEmpreendimento        6782 non-null   object
#  10  NumProcessoSIC           6781 non-null   object
#  11  NumAutoInfracao          6782 non-null   object
#  12  DscSituacaoArrecadacao   6782 non-null   object
#  13  DscSituacaoCredito       6782 non-null   object
# ...

# %%
dados.shape
# Out:
# (6782, 19)

# %% [markdown]
# ##### DROPANDO DADOS NULOS

# %%
dados.dropna(inplace=True)
# Out:
# C:\Users\Mateus\AppData\Local\Temp\ipykernel_22912\1165996664.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dados.dropna(inplace=True)

# %% [markdown]
# ##### RENOMEANDO COLUNAS

# %%
colunas_renomeadas = ['Data Geração Dados','Codigo Convenio Banco','Ano/Mes arrecadação','Primeira Data Vencimento cobrança','Data Incidencia Multa','Data Efetiva Pagamento da Cobrança','Total Dias Atrasado','Sigla/Nome Agente','CPF/CNPJ','Nome Empreendimento','Numero Processo SIC','Numero Auto Infracao','Situacao Arrecadacao','Situacao Credito','Valor Principal Cobranca Previsto Recebimento','Total Cobranca Previsto','Total Cobranca Pago','Diferenca Valor Cobranca e Valor Cobranca Pago','Valor Selic']
dados.columns=colunas_renomeadas

# %%
dados.head()
# Out:
#   Data Geração Dados  Codigo Convenio Banco  Ano/Mes arrecadação  \
# 0         2024-09-09                2940946               202109
# 1         2024-09-09                2600226               201412
# 2         2024-09-09                2600226               201412
# 3         2024-09-09                2940946               201708
# 4         2024-09-09                2940946               201708
#
#   Primeira Data Vencimento cobrança Data Incidencia Multa  \
# 0                        2021-09-21            2021-09-12
# 1                        2015-01-02            2015-06-22
# 2                        2015-01-02            2015-04-27
# 3                        2017-11-07            2017-12-30
# 4                        2018-01-06            2017-12-30
#
#   Data Efetiva Pagamento da Cobrança  Total Dias Atrasado  \
# 0                         2021-09-15                 -6.0
# 1                         2015-06-24                173.0
# ...

# %% [markdown]
# ##### CONVERSÃO DO TIPO DE DADOS DE DATAS (ESTÃO EM OBJECT) PARA DATETIME

# %%
dados['Data Geração Dados'] = pd.to_datetime(dados['Data Geração Dados'])
dados['Primeira Data Vencimento cobrança'] = pd.to_datetime(dados['Primeira Data Vencimento cobrança'])
dados['Data Incidencia Multa'] = pd.to_datetime(dados['Data Incidencia Multa'])
dados['Data Efetiva Pagamento da Cobrança'] = pd.to_datetime(dados['Data Efetiva Pagamento da Cobrança'])

# %%
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6782 entries, 0 to 6781
# Data columns (total 19 columns):
#  #   Column                                          Non-Null Count  Dtype
# ---  ------                                          --------------  -----
#  0   Data Geração Dados                              6782 non-null   datetime64[ns]
#  1   Codigo Convenio Banco                           6782 non-null   int64
#  2   Ano/Mes arrecadação                             6782 non-null   int64
#  3   Primeira Data Vencimento cobrança               6782 non-null   datetime64[ns]
#  4   Data Incidencia Multa                           6781 non-null   datetime64[ns]
#  5   Data Efetiva Pagamento da Cobrança              5574 non-null   datetime64[ns]
#  6   Total Dias Atrasado                             5574 non-null   float64
#  7   Sigla/Nome Agente                               6782 non-null   object
#  8   CPF/CNPJ                                        6782 non-null   int64
# ...

# %%
dados.head()
# Out:
#   Data Geração Dados  Codigo Convenio Banco  Ano/Mes arrecadação  \
# 0         2024-09-09                2940946               202109
# 1         2024-09-09                2600226               201412
# 2         2024-09-09                2600226               201412
# 3         2024-09-09                2940946               201708
# 4         2024-09-09                2940946               201708
#
#   Primeira Data Vencimento cobrança Data Incidencia Multa  \
# 0                        2021-09-21            2021-09-12
# 1                        2015-01-02            2015-06-22
# 2                        2015-01-02            2015-04-27
# 3                        2017-11-07            2017-12-30
# 4                        2018-01-06            2017-12-30
#
#   Data Efetiva Pagamento da Cobrança  Total Dias Atrasado  \
# 0                         2021-09-15                 -6.0
# 1                         2015-06-24                173.0
# ...

# %% [markdown]
# ##### CONVERSÃO DO TIPO DE DADOS DA COLUNA TOTAL DIAS ATRASADO DE FLOAT PARA INT

# %%
dados['Total Dias Atrasado']  = dados['Total Dias Atrasado'].astype(np.int64)
# Out:
# C:\Users\Mateus\AppData\Local\Temp\ipykernel_22912\1225301125.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dados['Total Dias Atrasado']  = dados['Total Dias Atrasado'].astype(np.int64)

# %%
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5548 entries, 0 to 6781
# Data columns (total 20 columns):
#  #   Column                                          Non-Null Count  Dtype
# ---  ------                                          --------------  -----
#  0   Data Geração Dados                              5548 non-null   datetime64[ns]
#  1   Codigo Convenio Banco                           5548 non-null   int64
#  2   Ano Arrecadao                                   5548 non-null   object
#  3   Mes Arrecadacao                                 5548 non-null   object
#  4   Primeira Data Vencimento cobrança               5548 non-null   datetime64[ns]
#  5   Data Incidencia Multa                           5548 non-null   datetime64[ns]
#  6   Data Efetiva Pagamento da Cobrança              5548 non-null   datetime64[ns]
#  7   Total Dias Atrasado                             5548 non-null   int64
#  8   Sigla/Nome Agente                               5548 non-null   object
# ...

# %% [markdown]
# ##### CONVERSÃO DO TIPO DE DADOS DA COLUNA Numero Processo SIC DE OBJECT PARA INT
# ##### VERIFICAR

# %%
dados['Numero Processo SIC'].value_counts().head(50)
# Out:
# Numero Processo SIC
# 485000007692010     51
# 485000023672010     51
# 485000024772009     51
# 485000027782012     50
# 485000035792011     50
# 485000044752008     50
# 485000027492011     50
# 485000029952012     49
# 485000030012016     39
# 485000036352014     36
# 485000056862012     36
# 485000048502015     36
# 41351/2018          35
# 298605/2019         29
# 229846/2020         29
# 485000034522017     28
# 51/200.777/2019     27
# 485000035212014     24
# PCEE/CEE/0036/18    21
# 485000038392006     19
# 202100029004425     16
# 590675/2018         16
# 485000038952017     15
# 485000000972017     15
# 485000025122019     14
# 485000023762019     14
# 485000051802020     14
# 485000015232015     14
# 485000072432007     13
# 485000031602017     13
# 485000052062012     13
# 485000037532007     13
# 485000046902009     13
# 485000059892009     13
# 485000029932012     13
# 485000059652009     13
# 485000009332013     13
# 485340039522012     13
# 485340022212013     13
# ...

# %% [markdown]
# ##### CONVERSÃO DO TIPO DE DADOS DA COLUNA Valor Principal Cobranca Previsto Recebimento DE STR PARA FLOAT

# %%
dados['Valor Principal Cobranca Previsto Recebimento'] = dados['Valor Principal Cobranca Previsto Recebimento'].apply(lambda x:x.replace(',','.'))
dados['Valor Principal Cobranca Previsto Recebimento'] =  dados['Valor Principal Cobranca Previsto Recebimento'].astype(np.float32)
# Out:
# C:\Users\Mateus\AppData\Local\Temp\ipykernel_22912\4276272823.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dados['Valor Principal Cobranca Previsto Recebimento'] = dados['Valor Principal Cobranca Previsto Recebimento'].apply(lambda x:x.replace(',','.'))
# C:\Users\Mateus\AppData\Local\Temp\ipykernel_22912\4276272823.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
dados['Valor Principal Cobranca Previsto Recebimento'] = np.ceil(dados['Valor Principal Cobranca Previsto Recebimento'])
# Out:
# C:\Users\Mateus\AppData\Local\Temp\ipykernel_22912\997248398.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dados['Valor Principal Cobranca Previsto Recebimento'] = np.ceil(dados['Valor Principal Cobranca Previsto Recebimento'])

# %%
dados.head()
# Out:
#   Data Geração Dados  Codigo Convenio Banco Ano Arrecadao Mes Arrecadacao  \
# 0         2024-09-09                2940946          2021              09
# 1         2024-09-09                2600226          2014              12
# 2         2024-09-09                2600226          2014              12
# 3         2024-09-09                2940946          2017              08
# 4         2024-09-09                2940946          2017              08
#
#   Primeira Data Vencimento cobrança Data Incidencia Multa  \
# 0                        2021-09-21            2021-09-12
# 1                        2015-01-02            2015-06-22
# 2                        2015-01-02            2015-04-27
# 3                        2017-11-07            2017-12-30
# 4                        2018-01-06            2017-12-30
#
#   Data Efetiva Pagamento da Cobrança  Total Dias Atrasado  \
# 0                         2021-09-15                   -6
# ...

# %% [markdown]
# ##### TRANSFORMANDO COLUNAS LOWERCASE IN UPPERCASE

# %%
dados['Situacao Arrecadacao'] = dados['Situacao Arrecadacao'].str.upper()
dados['Situacao Credito'] = dados['Situacao Credito'].str.upper()

# %%
dados.head()
# Out:
#   Data Geração Dados  Codigo Convenio Banco  Ano/Mes arrecadação  \
# 0         2024-09-09                2940946               202109
# 1         2024-09-09                2600226               201412
# 2         2024-09-09                2600226               201412
# 3         2024-09-09                2940946               201708
# 4         2024-09-09                2940946               201708
#
#   Primeira Data Vencimento cobrança Data Incidencia Multa  \
# 0                        2021-09-21            2021-09-12
# 1                        2015-01-02            2015-06-22
# 2                        2015-01-02            2015-04-27
# 3                        2017-11-07            2017-12-30
# 4                        2018-01-06            2017-12-30
#
#   Data Efetiva Pagamento da Cobrança  Total Dias Atrasado  \
# 0                         2021-09-15                 -6.0
# 1                         2015-06-24                173.0
# ...

# %% [markdown]
# ##### SEPARAÇÃO DE VALORES ANO E MES DA MESMA COLUNA

# %%
dados['Ano'] = dados_teste['Ano/Mes arrecadação'].str[:4]
dados['Mes'] = dados_teste['Ano/Mes arrecadação'].str[4:]

# %%
dados.head()
# Out:
#   Data Geração Dados  Codigo Convenio Banco   Ano Mes  \
# 0         2024-09-09                2940946  2021  09
# 1         2024-09-09                2600226  2014  12
# 2         2024-09-09                2600226  2014  12
# 3         2024-09-09                2940946  2017  08
# 4         2024-09-09                2940946  2017  08
#
#   Primeira Data Vencimento cobrança Data Incidencia Multa  \
# 0                        2021-09-21            2021-09-12
# 1                        2015-01-02            2015-06-22
# 2                        2015-01-02            2015-04-27
# 3                        2017-11-07            2017-12-30
# 4                        2018-01-06            2017-12-30
#
#   Data Efetiva Pagamento da Cobrança  Total Dias Atrasado  \
# 0                         2021-09-15                 -6.0
# 1                         2015-06-24                173.0
# 2                         2015-06-24                173.0
# ...

# %% [markdown]
# ##### REORGANIZAÇÃO DAS COLUNAS

# %%
nova_ordem = [
    'Data Geração Dados',
    'Codigo Convenio Banco',
    'Ano Arrecadao',
    'Mes Arrecadacao',
    'Primeira Data Vencimento cobrança',
    'Data Incidencia Multa',
    'Data Efetiva Pagamento da Cobrança',
    'Total Dias Atrasado',
    'Sigla/Nome Agente',
    'CPF/CNPJ',
    'Nome Empreendimento',
    'Numero Processo SIC',
    'Numero Auto Infracao',
    'Situacao Arrecadacao',
    'Situacao Credito',
    'Valor Principal Cobranca Previsto Recebimento',
    'Total Cobranca Previsto',
    'Total Cobranca Pago',
    'Diferenca Valor Cobranca e Valor Cobranca Pago',
    'Valor Selic',
    'Ano',
    'Mes'
]

# %%
dados = dados[nova_ordem]

# %%
### Validação do script
dados.head()
# Out:
#   Data Geração Dados  Codigo Convenio Banco Ano Arrecadao Mes Arrecadacao  \
# 0         2024-09-09                2940946          2021              09
# 1         2024-09-09                2600226          2014              12
# 2         2024-09-09                2600226          2014              12
# 3         2024-09-09                2940946          2017              08
# 4         2024-09-09                2940946          2017              08
#
#   Primeira Data Vencimento cobrança Data Incidencia Multa  \
# 0                        2021-09-21            2021-09-12
# 1                        2015-01-02            2015-06-22
# 2                        2015-01-02            2015-04-27
# 3                        2017-11-07            2017-12-30
# 4                        2018-01-06            2017-12-30
#
#   Data Efetiva Pagamento da Cobrança  Total Dias Atrasado  \
# 0                         2021-09-15                 -6.0
# ...

# %%
dados.drop('Ano/Mes arrecadação',axis=1,inplace=True)
# Out:
# C:\Users\Mateus\AppData\Local\Temp\ipykernel_22912\3298024039.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dados.drop('Ano/Mes arrecadação',axis=1,inplace=True)

# %%
dados.drop('Ano',axis=1,inplace=True)
dados.drop('Mes',axis=1,inplace=True)
# Out:
# C:\Users\Mateus\AppData\Local\Temp\ipykernel_22912\3602082741.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dados.drop('Ano',axis=1,inplace=True)
# C:\Users\Mateus\AppData\Local\Temp\ipykernel_22912\3602082741.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dados.drop('Mes',axis=1,inplace=True)

# %%
dados['Ano Arrecadao'] = dados['Ano']
dados['Mes Arrecadacao'] = dados['Mes']

# %%
dados.head()
# Out:
#   Data Geração Dados  Codigo Convenio Banco Ano Arrecadao Mes Arrecadacao  \
# 0         2024-09-09                2940946          2021              09
# 1         2024-09-09                2600226          2014              12
# 2         2024-09-09                2600226          2014              12
# 3         2024-09-09                2940946          2017              08
# 4         2024-09-09                2940946          2017              08
#
#   Primeira Data Vencimento cobrança Data Incidencia Multa  \
# 0                        2021-09-21            2021-09-12
# 1                        2015-01-02            2015-06-22
# 2                        2015-01-02            2015-04-27
# 3                        2017-11-07            2017-12-30
# 4                        2018-01-06            2017-12-30
#
#   Data Efetiva Pagamento da Cobrança  Total Dias Atrasado  \
# 0                         2021-09-15                   -6
# ...

# %% [markdown]
# ##### CONVERSÃO TIPO DE DADOS DA COLUNA Total Cobranca Previsto DE STR PARA FLOAT

# %%
dados['Total Cobranca Previsto'] = dados['Total Cobranca Previsto'].apply(lambda x:x.replace(',','.'))
dados['Total Cobranca Previsto'] = dados['Total Cobranca Previsto'].astype(np.float32)

# %%
dados['Total Cobranca Previsto'] = round(dados['Total Cobranca Previsto'],2)
# Out:
# C:\Users\Mateus\AppData\Local\Temp\ipykernel_22912\3935232316.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dados['Total Cobranca Previsto'] = round(dados['Total Cobranca Previsto'],2)

# %%
dados.head(10)
# Out:
#   Data Geração Dados  Codigo Convenio Banco Ano Arrecadao Mes Arrecadacao  \
# 0         2024-09-09                2940946          2021              09
# 1         2024-09-09                2600226          2014              12
# 2         2024-09-09                2600226          2014              12
# 3         2024-09-09                2940946          2017              08
# 4         2024-09-09                2940946          2017              08
# 5         2024-09-09                2940946          2017              08
# 6         2024-09-09                2940946          2017              08
# 7         2024-09-09                2940946          2017              08
# 8         2024-09-09                2940946          2017              08
# 9         2024-09-09                2940946          2017              08
#
#   Primeira Data Vencimento cobrança Data Incidencia Multa  \
# 0                        2021-09-21            2021-09-12
# ...

# %%
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5548 entries, 0 to 6781
# Data columns (total 20 columns):
#  #   Column                                          Non-Null Count  Dtype
# ---  ------                                          --------------  -----
#  0   Data Geração Dados                              5548 non-null   datetime64[ns]
#  1   Codigo Convenio Banco                           5548 non-null   int64
#  2   Ano Arrecadao                                   5548 non-null   object
#  3   Mes Arrecadacao                                 5548 non-null   object
#  4   Primeira Data Vencimento cobrança               5548 non-null   datetime64[ns]
#  5   Data Incidencia Multa                           5548 non-null   datetime64[ns]
#  6   Data Efetiva Pagamento da Cobrança              5548 non-null   datetime64[ns]
#  7   Total Dias Atrasado                             5548 non-null   int64
#  8   Sigla/Nome Agente                               5548 non-null   object
# ...

# %% [markdown]
# ##### CONVERSÃO TIPO DE DADOS DA COLUNA Total Cobranca PagoDE STR PARA FLOAT

# %%
dados['Total Cobranca Pago'] = dados['Total Cobranca Pago'].apply(lambda x:x.replace(',','.'))
dados['Total Cobranca Pago'] = dados['Total Cobranca Pago'].astype(np.float32)

# %%
dados['Total Cobranca Pago'] = np.ceil(dados['Total Cobranca Pago'])
# Out:
# C:\Users\Mateus\AppData\Local\Temp\ipykernel_22912\2282828560.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dados['Total Cobranca Pago'] = np.ceil(dados['Total Cobranca Pago'])

# %%
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5548 entries, 0 to 6781
# Data columns (total 20 columns):
#  #   Column                                          Non-Null Count  Dtype
# ---  ------                                          --------------  -----
#  0   Data Geração Dados                              5548 non-null   datetime64[ns]
#  1   Codigo Convenio Banco                           5548 non-null   int64
#  2   Ano Arrecadao                                   5548 non-null   object
#  3   Mes Arrecadacao                                 5548 non-null   object
#  4   Primeira Data Vencimento cobrança               5548 non-null   datetime64[ns]
#  5   Data Incidencia Multa                           5548 non-null   datetime64[ns]
#  6   Data Efetiva Pagamento da Cobrança              5548 non-null   datetime64[ns]
#  7   Total Dias Atrasado                             5548 non-null   int64
#  8   Sigla/Nome Agente                               5548 non-null   object
# ...

# %% [markdown]
# ##### CALCULO DA DIFERENCA ENTRE O VALOR TOTAL DA Total Cobranca Previsto - Total Cobranca Pago

# %%
dados['Diferenca Valor Cobranca e Valor Cobranca Pago'] = dados['Total Cobranca Previsto'] - dados['Total Cobranca Pago']
# Out:
# C:\Users\Mateus\AppData\Local\Temp\ipykernel_22912\3398589318.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dados['Diferenca Valor Cobranca e Valor Cobranca Pago'] = dados['Total Cobranca Previsto'] - dados['Total Cobranca Pago']

# %%
dados.head(10)
# Out:
#   Data Geração Dados  Codigo Convenio Banco Ano Arrecadao Mes Arrecadacao  \
# 0         2024-09-09                2940946          2021              09
# 1         2024-09-09                2600226          2014              12
# 2         2024-09-09                2600226          2014              12
# 3         2024-09-09                2940946          2017              08
# 4         2024-09-09                2940946          2017              08
# 5         2024-09-09                2940946          2017              08
# 6         2024-09-09                2940946          2017              08
# 7         2024-09-09                2940946          2017              08
# 8         2024-09-09                2940946          2017              08
# 9         2024-09-09                2940946          2017              08
#
#   Primeira Data Vencimento cobrança Data Incidencia Multa  \
# 0                        2021-09-21            2021-09-12
# ...

# %%
dados_teste = dados.copy()

# %%
dados.head()
# Out:
#   Data Geração Dados  Codigo Convenio Banco Ano Arrecadao Mes Arrecadacao  \
# 0         2024-09-09                2940946          2021              09
# 1         2024-09-09                2600226          2014              12
# 2         2024-09-09                2600226          2014              12
# 3         2024-09-09                2940946          2017              08
# 4         2024-09-09                2940946          2017              08
#
#   Primeira Data Vencimento cobrança Data Incidencia Multa  \
# 0                        2021-09-21            2021-09-12
# 1                        2015-01-02            2015-06-22
# 2                        2015-01-02            2015-04-27
# 3                        2017-11-07            2017-12-30
# 4                        2018-01-06            2017-12-30
#
#   Data Efetiva Pagamento da Cobrança  Total Dias Atrasado  \
# 0                         2021-09-15                   -6
# ...

# %%
dados['Diferenca Valor Cobranca e Valor Cobranca Pago']
# Out:
# 0         ,00
# 1         ,00
# 2         ,00
# 3         ,00
# 4         ,00
#         ...
# 6776      ,00
# 6777      ,00
# 6779    20,45
# 6780    80,60
# 6781      ,00
# Name: Diferenca Valor Cobranca e Valor Cobranca Pago, Length: 5548, dtype: object

# %%
dados_teste['Diferenca Valor Cobranca e Valor Cobranca Pago'] =  dados_teste['Total Cobranca Previsto'] - dados_teste['Total Cobranca Pago']

# %%
dados_teste
# Out:
#      Data Geração Dados  Codigo Convenio Banco Ano Arrecadao Mes Arrecadacao  \
# 0            2024-09-09                2940946          2021              09
# 1            2024-09-09                2600226          2014              12
# 2            2024-09-09                2600226          2014              12
# 3            2024-09-09                2940946          2017              08
# 4            2024-09-09                2940946          2017              08
# ...                 ...                    ...           ...             ...
# 6776         2024-09-09                2940946          2018              11
# 6777         2024-09-09                2940946          2018              11
# 6779         2024-09-09                2940946          2018              11
# 6780         2024-09-09                2940946          2018              11
# 6781         2024-09-09                2940946          2020              08
#
# ...

# %%
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5548 entries, 0 to 6781
# Data columns (total 20 columns):
#  #   Column                                          Non-Null Count  Dtype
# ---  ------                                          --------------  -----
#  0   Data Geração Dados                              5548 non-null   datetime64[ns]
#  1   Codigo Convenio Banco                           5548 non-null   int64
#  2   Ano Arrecadao                                   5548 non-null   object
#  3   Mes Arrecadacao                                 5548 non-null   object
#  4   Primeira Data Vencimento cobrança               5548 non-null   datetime64[ns]
#  5   Data Incidencia Multa                           5548 non-null   datetime64[ns]
#  6   Data Efetiva Pagamento da Cobrança              5548 non-null   datetime64[ns]
#  7   Total Dias Atrasado                             5548 non-null   int64
#  8   Sigla/Nome Agente                               5548 non-null   object
# ...
